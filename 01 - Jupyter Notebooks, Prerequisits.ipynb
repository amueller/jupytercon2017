# %% [markdown]
# # Jupyter notebooks

# %% [markdown]
# ## Getting Help

# %% [markdown]
# ## Plotting with matplotlib

# %% [markdown]
# ## Best practices for data analysis

# %% [markdown]
# # Matplotlib Refresher
